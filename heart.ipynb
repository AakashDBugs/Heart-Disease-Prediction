# %% [markdown]
# ### Heart Disease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/BIA /Dataset/heart.csv')

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### Visualization

# %%
#check count of Categorical features.
categorical_features = df.select_dtypes(include=['float64', 'int64']).columns
plt.figure(figsize=(15,80), facecolor='white')
plotnumber =1
for categorical_feature in categorical_features:
    ax = plt.subplot(12,3,plotnumber)
    sns.countplot(y=categorical_feature,data=df)
    plt.xlabel(categorical_feature)
    plt.title(categorical_feature)
    plotnumber+=1
plt.show()

# %% [markdown]
# Note: The data i recieved already was label encoded so i had to print based on all float and int values and not the "object value" so in above plots we look at 1,0 values

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(20,60), facecolor='white')
plotnumber =1
for numerical_cols in numerical_cols:
    ax = plt.subplot(12,3,plotnumber)
    sns.distplot(df[numerical_cols])
    plt.xlabel(numerical_cols)
    plotnumber+=1
plt.show()

# %% [markdown]
# (refer to the above note) and in this plot we check the distibuion of data, we can find some skivness in someplot

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(20,60), facecolor='white')
plotnumber =1
for numerical_cols in numerical_cols:
    ax = plt.subplot(12,3,plotnumber)
    sns.boxplot(df[numerical_cols])
    plt.xlabel(numerical_cols)
    plotnumber+=1

# %% [markdown]
# This plot shows us if there are any outliers as such (remember we have to refer to the 1st Note above) so after cross checking they are correct values hence could not be removed

# %%
correlation = df.corr()

# %%
plt.figure(figsize = (15,9))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f',annot=True, annot_kws={'size':8}, cmap='Reds')
# Out:
# <Axes: >

# %%
x = df.drop(['target'],axis=1)
y= df['target']

# %% [markdown]
# ### T-T-S

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# Logistic Regression
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
lr_predictions = lr_model.predict(x_test)
lr_accuracy = accuracy_score(y_test, lr_predictions)
print(f"Logistic Regression Accuracy: {lr_accuracy:.2f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, lr_predictions))
print("\nClassification Report:")
print(classification_report(y_test, lr_predictions))
# Out:
# Logistic Regression Accuracy: 0.85
# Confusion Matrix:
# [[82 23]
#  [ 7 93]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85       105
#            1       0.80      0.93      0.86       100
#
#     accuracy                           0.85       205
#    macro avg       0.86      0.86      0.85       205
# weighted avg       0.86      0.85      0.85       205

# %%
# Support Vector Machine (SVM)
svm_model = SVC()
svm_model.fit(x_train, y_train)
svm_predictions = svm_model.predict(x_test)
svm_accuracy = accuracy_score(y_test, svm_predictions)
print(f"\nSVM Accuracy: {svm_accuracy:.2f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, svm_predictions))
print("\nClassification Report:")
print(classification_report(y_test, svm_predictions))
# Out:
# SVM Accuracy: 0.73
# Confusion Matrix:
# [[61 44]
#  [11 89]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.58      0.69       105
#            1       0.67      0.89      0.76       100
#
#     accuracy                           0.73       205
#    macro avg       0.76      0.74      0.73       205
# weighted avg       0.76      0.73      0.73       205

# %%
# Decision Trees
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)
dt_predictions = dt_model.predict(x_test)
dt_accuracy = accuracy_score(y_test, dt_predictions)
print(f"Decision Trees Accuracy: {dt_accuracy:.2f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, dt_predictions))
print("\nClassification Report:")
print(classification_report(y_test, dt_predictions))
# Out:
# Decision Trees Accuracy: 0.98
# Confusion Matrix:
# [[101   4]
#  [  0 100]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.96      1.00      0.98       100
#
#     accuracy                           0.98       205
#    macro avg       0.98      0.98      0.98       205
# weighted avg       0.98      0.98      0.98       205
